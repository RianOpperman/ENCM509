# %% [markdown]
# <!-- DON'T EDIT THIS CELL! -->
# <!-- TYPE SHIFT+ENTER AND GO TO THE NEXT CELL -->
#
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np

#import tensorflow.keras as keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from os import listdir
from os.path import isfile, join, dirname, abspath
from tensorflow.keras.metrics import Precision, Recall
from warnings import simplefilter
from tensorflow.keras import models, layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.layers import Bidirectional
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
# the length of records (if shorter, we need to add some zero rows)
NUMBER_TIMESTEPS = 150
# the number of features (from the data)
NUMBER_FEATURES = 203
# the number of classes/gestures
NUMBER_OUTPUTS = 3
# you can encode more than 1 but for this example we have binary output (circle/swipe)

# %%
# the directory where your data is
mypath_RO = '../data/genuine/RO'
mypath_imposter = '../data/imposter'
mypath_MA = '../data/genuine/MA'

# creating a list with all the filenames
datafiles_RO = [f for f in listdir('../data/genuine/RO') if isfile(join(mypath_RO, f))]
datafiles_MA = [f for f in listdir('../data/genuine/MA') if isfile(join(mypath_MA, f))]
datafiles_imposter = [f for f in listdir('../data/imposter') if isfile(join(mypath_imposter, f))]
print(datafiles_MA)
# Out:
# ['MA_left_1.csv', 'MA_left_10.csv', 'MA_left_2.csv', 'MA_left_3.csv', 'MA_left_4.csv', 'MA_left_5.csv', 'MA_left_6.csv', 'MA_left_7.csv', 'MA_left_8.csv', 'MA_left_9.csv', 'MA_right_1.csv', 'MA_right_10.csv', 'MA_right_2.csv', 'MA_right_3.csv', 'MA_right_4.csv', 'MA_right_5.csv', 'MA_right_6.csv', 'MA_right_7.csv', 'MA_right_8.csv', 'MA_right_9.csv']

# %%
# choose data we need
columns = ['handPalmPosition_X','handPalmPosition_Y','handPalmPosition_Z',
          'pitch', 'roll', 'yaw', 'GenuineRO', 'GenuineMA', 'imposter',
          'wristPosition_X', 'wristPosition_Y','wristPosition_Z',
          'elbowPosition_X', 'elbowPosition_Y', 'elbowPosition_Z', 'handType']

finger_names = ['Thumb', 'Index', 'Middle', 'Ring', 'Pinky']
bone_names = ['Metacarpal', 'Proximal', 'Intermediate', 'Distal']
    
for finger in finger_names:
    columns.append(finger + 'Length')
    columns.append(finger + 'Width')

for finger in finger_names:
    for bone in bone_names:
        columns.append(finger + bone + 'Start_X')
        columns.append(finger + bone + 'Start_Y')
        columns.append(finger + bone + 'Start_Z')
        columns.append(finger + bone + 'End_X')
        columns.append(finger + bone + 'End_Y')
        columns.append(finger + bone + 'End_Z')
        columns.append(finger + bone + 'Direction_X') 
        columns.append(finger + bone + 'Direction_Y') 
        columns.append(finger + bone + 'Direction_Z')

# %%
columns_to_expand = [
    'handPalmPosition', 'wristPosition', 'elbowPosition',
    'ThumbMetacarpalStart', 'ThumbMetacarpalEnd', 'ThumbMetacarpalDirection',
    'ThumbProximalStart', 'ThumbProximalEnd', 'ThumbProximalDirection',
    'ThumbIntermediateStart', 'ThumbIntermediateEnd', 'ThumbIntermediateDirection',
    'ThumbDistalStart', 'ThumbDistalEnd', 'ThumbDistalDirection',
    'IndexMetacarpalStart', 'IndexMetacarpalEnd', 'IndexMetacarpalDirection',
    'IndexProximalStart', 'IndexProximalEnd', 'IndexProximalDirection',
    'IndexIntermediateStart', 'IndexIntermediateEnd', 'IndexIntermediateDirection',
    'IndexDistalStart', 'IndexDistalEnd', 'IndexDistalDirection',
    'MiddleMetacarpalStart', 'MiddleMetacarpalEnd', 'MiddleMetacarpalDirection',
    'MiddleProximalStart', 'MiddleProximalEnd', 'MiddleProximalDirection',
    'MiddleIntermediateStart', 'MiddleIntermediateEnd', 'MiddleIntermediateDirection',
    'MiddleDistalStart', 'MiddleDistalEnd', 'MiddleDistalDirection',
    'RingMetacarpalStart', 'RingMetacarpalEnd', 'RingMetacarpalDirection',
    'RingProximalStart', 'RingProximalEnd', 'RingProximalDirection',
    'RingIntermediateStart', 'RingIntermediateEnd', 'RingIntermediateDirection',
    'RingDistalStart', 'RingDistalEnd', 'RingDistalDirection',
    'PinkyMetacarpalStart', 'PinkyMetacarpalEnd', 'PinkyMetacarpalDirection',
    'PinkyProximalStart', 'PinkyProximalEnd', 'PinkyProximalDirection',
    'PinkyIntermediateStart', 'PinkyIntermediateEnd', 'PinkyIntermediateDirection',
    'PinkyDistalStart', 'PinkyDistalEnd', 'PinkyDistalDirection'
]

# %%
# We need to set some ground truth 

genuine_ro = [f for f in listdir('../data/genuine/RO') if isfile(join(mypath_RO, f))]
imposter = [f for f in listdir('../data/imposter') if isfile(join(mypath_imposter, f))]
genuine_ma = [f for f in listdir('../data/genuine/MA') if isfile(join(mypath_MA, f))]

for c in genuine_ro:
    relative_path = mypath_RO + '/' + c
    print(relative_path)
    tmp = pd.read_csv(relative_path)
    tmp['imposter'] = 0
    tmp['GenuineRO'] = 1
    tmp['GenuineMA'] = 0
    tmp.to_csv(path_or_buf=relative_path, index=False)

for c in genuine_ma:
    relative_path = mypath_MA + '/' + c
    print(relative_path)
    tmp = pd.read_csv(relative_path)
    tmp['imposter'] = 0
    tmp['GenuineRO'] = 0
    tmp['GenuineMA'] = 1
    tmp.to_csv(path_or_buf=relative_path, index=False)

for s in imposter:
    relative_path = mypath_imposter + '/' + s
    print(relative_path)
    tmp = pd.read_csv(relative_path)
    tmp['imposter'] = 1
    tmp['GenuineRO'] = 0
    tmp['GenuineMA'] = 0
    tmp.to_csv(path_or_buf=relative_path, index=False)
# Out:
# ../data/genuine/RO/RO_left_1.csv
# ../data/genuine/RO/RO_left_10.csv
# ../data/genuine/RO/RO_left_2.csv
# ../data/genuine/RO/RO_left_3.csv
# ../data/genuine/RO/RO_left_4.csv
# ../data/genuine/RO/RO_left_5.csv
# ../data/genuine/RO/RO_left_6.csv
# ../data/genuine/RO/RO_left_7.csv
# ../data/genuine/RO/RO_left_8.csv
# ../data/genuine/RO/RO_left_9.csv
# ../data/genuine/RO/RO_right_1.csv
# ../data/genuine/RO/RO_right_10.csv
# ../data/genuine/RO/RO_right_2.csv
# ../data/genuine/RO/RO_right_3.csv
# ../data/genuine/RO/RO_right_4.csv
# ../data/genuine/RO/RO_right_5.csv
# ../data/genuine/RO/RO_right_6.csv
# ../data/genuine/RO/RO_right_7.csv
# ../data/genuine/RO/RO_right_8.csv
# ../data/genuine/RO/RO_right_9.csv
# ../data/genuine/MA/MA_left_1.csv
# ../data/genuine/MA/MA_left_10.csv
# ../data/genuine/MA/MA_left_2.csv
# ../data/genuine/MA/MA_left_3.csv
# ../data/genuine/MA/MA_left_4.csv
# ../data/genuine/MA/MA_left_5.csv
# ../data/genuine/MA/MA_left_6.csv
# ../data/genuine/MA/MA_left_7.csv
# ../data/genuine/MA/MA_left_8.csv
# ../data/genuine/MA/MA_left_9.csv
# ../data/genuine/MA/MA_right_1.csv
# ../data/genuine/MA/MA_right_10.csv
# ../data/genuine/MA/MA_right_2.csv
# ../data/genuine/MA/MA_right_3.csv
# ../data/genuine/MA/MA_right_4.csv
# ../data/genuine/MA/MA_right_5.csv
# ../data/genuine/MA/MA_right_6.csv
# ../data/genuine/MA/MA_right_7.csv
# ../data/genuine/MA/MA_right_8.csv
# ../data/genuine/MA/MA_right_9.csv
# ../data/imposter/MA_gibb_1.csv
# ../data/imposter/MA_gibb_2.csv
# ../data/imposter/MA_gibb_3.csv
# ../data/imposter/MA_left_RO_1.csv
# ../data/imposter/MA_left_RO_2.csv
# ../data/imposter/MA_left_RO_3.csv
# ../data/imposter/MA_left_RO_4.csv
# ../data/imposter/MA_left_RO_5.csv
# ../data/imposter/MA_right_RO_1.csv
# ../data/imposter/MA_right_RO_2.csv
# ../data/imposter/MA_right_RO_3.csv
# ../data/imposter/MA_right_RO_4.csv
# ../data/imposter/MA_right_RO_5.csv
# ../data/imposter/RO_gibb_1.csv
# ../data/imposter/RO_gibb_2.csv
# ../data/imposter/RO_gibb_3.csv
# ../data/imposter/RO_gibb_4.csv
# ../data/imposter/RO_gibb_5.csv
# ../data/imposter/RO_gibb_6.csv
# ../data/imposter/RO_left_MA_1.csv
# ../data/imposter/RO_left_MA_10.csv
# ../data/imposter/RO_left_MA_2.csv
# ../data/imposter/RO_left_MA_3.csv
# ../data/imposter/RO_left_MA_4.csv
# ../data/imposter/RO_left_MA_5.csv
# ../data/imposter/RO_left_MA_6.csv
# ../data/imposter/RO_left_MA_7.csv
# ../data/imposter/RO_left_MA_8.csv
# ../data/imposter/RO_left_MA_9.csv
# ../data/imposter/RO_right_MA_1.csv
# ../data/imposter/RO_right_MA_10.csv
# ../data/imposter/RO_right_MA_2.csv
# ../data/imposter/RO_right_MA_3.csv
# ../data/imposter/RO_right_MA_4.csv
# ../data/imposter/RO_right_MA_5.csv
# ../data/imposter/RO_right_MA_6.csv
# ../data/imposter/RO_right_MA_7.csv
# ../data/imposter/RO_right_MA_8.csv
# ../data/imposter/RO_right_MA_9.csv

# %%
def split_and_expand(df, column_name_prefix):
    columns = [f'{column_name_prefix}_{i}' for i in ['X', 'Y', 'Z']]
    df[columns] = df[column_name_prefix].str[1:-1].str.split(',', expand=True)
    df.drop(columns=[column_name_prefix], inplace=True)

# %%
# Features
x = []
# Labels
y = []

# %%
def process_data(datafiles, use_prerecorded=False, columns_to_expand=None, path='./'):
    num = 1  # Counter for saving files (if needed)
    
    for sample in datafiles:
        relative_path = path + '/' + f'/{sample}' if use_prerecorded else path + '/' + f'/{sample}'
        tmp = pd.read_csv(relative_path, usecols=columns if use_prerecorded else None)
        
        # trying something
        # Simple handType mapping: strings to integers
        if 'handType' in tmp.columns:
            tmp['handType'] = tmp['handType'].replace({
                'Right hand': 1,
                'Left hand': 2
            }).fillna(0).astype(float)

        
        if not use_prerecorded and columns_to_expand:
            for col in columns_to_expand:
                split_and_expand(tmp, col)
        
        tmp.fillna(0, inplace=True)
        tmp.replace('', 0, inplace=True)
        # tmp = tmp.astype(float)
        
        print(f'{relative_path}\nsize raw = {tmp.shape}')
        tmp = tmp.reindex(range(NUMBER_TIMESTEPS), fill_value=0) if tmp.shape[0] < NUMBER_TIMESTEPS else tmp.head(NUMBER_TIMESTEPS)
        print(f'size normalized = {tmp.shape}')
        
        tmp_x = tmp.drop(columns=['GenuineRO', 'GenuineMA', 'imposter'], errors='ignore')
        tmp_x.drop(columns=[col for col in tmp_x.columns if col not in columns], inplace=True)
        tmp_y = tmp[['GenuineRO', 'GenuineMA', 'imposter']]
        
        if use_prerecorded:
            path_str = f'save/{num}.csv'
            # tmp_x.to_csv(path_str)
            num += 1
        
        x.append(tmp_x)
        y.append(tmp_y)

# %%
# Run with YOUR RECORDED DATA
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

process_data(datafiles_RO, use_prerecorded=False, columns_to_expand=columns_to_expand, path=mypath_RO)
process_data(datafiles_MA, use_prerecorded=False, columns_to_expand=columns_to_expand, path=mypath_MA)
process_data(datafiles_imposter, use_prerecorded=False, columns_to_expand=columns_to_expand, path=mypath_imposter)


# Run with OUR prerecorded data
# process_data(datafiles, use_prerecorded=True)

# process_data(...,  use_prerecorded = True or False)
# Out:
# ../data/genuine/RO//RO_left_1.csv
# size raw = (129, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_left_10.csv
# size raw = (138, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_left_2.csv
# size raw = (119, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_left_3.csv
# size raw = (127, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_left_4.csv
# size raw = (127, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_left_5.csv
# size raw = (129, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_left_6.csv
# size raw = (116, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_left_7.csv
# size raw = (120, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_left_8.csv
# size raw = (153, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_left_9.csv
# size raw = (121, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_1.csv
# size raw = (176, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_10.csv
# size raw = (110, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_2.csv
# size raw = (195, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_3.csv
# size raw = (182, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_4.csv
# size raw = (133, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_5.csv
# size raw = (136, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_6.csv
# size raw = (101, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_7.csv
# size raw = (127, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_8.csv
# size raw = (124, 236)
# size normalized = (150, 236)
# ../data/genuine/RO//RO_right_9.csv
# size raw = (129, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_1.csv
# size raw = (153, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_10.csv
# size raw = (183, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_2.csv
# size raw = (127, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_3.csv
# size raw = (159, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_4.csv
# size raw = (178, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_5.csv
# size raw = (123, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_6.csv
# size raw = (169, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_7.csv
# size raw = (155, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_8.csv
# size raw = (177, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_left_9.csv
# size raw = (182, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_1.csv
# size raw = (133, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_10.csv
# size raw = (210, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_2.csv
# size raw = (162, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_3.csv
# size raw = (171, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_4.csv
# size raw = (152, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_5.csv
# size raw = (176, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_6.csv
# size raw = (112, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_7.csv
# size raw = (184, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_8.csv
# size raw = (96, 236)
# size normalized = (150, 236)
# ../data/genuine/MA//MA_right_9.csv
# size raw = (171, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_gibb_1.csv
# size raw = (87, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_gibb_2.csv
# size raw = (89, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_gibb_3.csv
# size raw = (118, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_left_RO_1.csv
# size raw = (145, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_left_RO_2.csv
# size raw = (113, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_left_RO_3.csv
# size raw = (156, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_left_RO_4.csv
# size raw = (124, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_left_RO_5.csv
# size raw = (106, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_right_RO_1.csv
# size raw = (139, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_right_RO_2.csv
# size raw = (137, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_right_RO_3.csv
# size raw = (154, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_right_RO_4.csv
# size raw = (143, 236)
# size normalized = (150, 236)
# ../data/imposter//MA_right_RO_5.csv
# size raw = (147, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_gibb_1.csv
# size raw = (144, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_gibb_2.csv
# size raw = (159, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_gibb_3.csv
# size raw = (196, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_gibb_4.csv
# size raw = (166, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_gibb_5.csv
# size raw = (183, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_gibb_6.csv
# size raw = (102, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_1.csv
# size raw = (127, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_10.csv
# size raw = (108, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_2.csv
# size raw = (69, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_3.csv
# size raw = (73, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_4.csv
# size raw = (179, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_5.csv
# size raw = (143, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_6.csv
# size raw = (142, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_7.csv
# size raw = (141, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_8.csv
# size raw = (118, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_left_MA_9.csv
# size raw = (129, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_1.csv
# size raw = (188, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_10.csv
# size raw = (137, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_2.csv
# size raw = (182, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_3.csv
# size raw = (162, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_4.csv
# size raw = (106, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_5.csv
# size raw = (143, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_6.csv
# size raw = (176, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_7.csv
# size raw = (160, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_8.csv
# size raw = (131, 236)
# size normalized = (150, 236)
# ../data/imposter//RO_right_MA_9.csv
# size raw = (134, 236)
# size normalized = (150, 236)

# %% [markdown]
# # Classification

# %%
np.array(y[0].loc[0])
# Out:
# array([1, 0, 0], dtype=int64)

# %%
# Each sample requires labels of [1,NUMBER_OUTPUTS] size (not a list)
y_new = list()
for cur_label in y:
    tmp = np.array(cur_label.loc[0])
    y_new.append(tmp)
y = np.array(y_new)
#print(y)

# %%
# Set a percentage of test set fraction
test_size = 0.20 # 30%

# Divide data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=test_size, shuffle=True, stratify=y)
len_train = len(X_train)
len_test = len(X_test)

print ('Number of train samples = {}\nNumber of test samples = {}'.format(len_train, len_test))
print ('There is ',type(X_train),' of ',type(X_train[0]))

# Turn list(DataFrame) into numpy.ndarray with [len_train, NUMBER_TIMESTEPS, NUMBER_FEATURES]
X_train = np.array(X_train, dtype=float)
X_test = np.array(X_test, dtype=float)
print('The list was turned into <numpy.ndarray>')
# Out:
# Number of train samples = 63
# Number of test samples = 16
# There is  <class 'list'>  of  <class 'pandas.core.frame.DataFrame'>
# The list was turned into <numpy.ndarray>

# %%
class AttentionLayer(layers.Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()

    def call(self, inputs):
        # inputs shape: (batch_size, timesteps, features)
        score = tf.nn.tanh(inputs)
        attention_weights = tf.nn.softmax(score, axis=1)
        context_vector = attention_weights * inputs
        return tf.reduce_sum(context_vector, axis=1)

# %%
NUMBER_TIMESTEPS = 150
# Make sure NUMBER_FEATURES and NUMBER_OUTPUTS are defined appropriately

def build_model():
    model = models.Sequential()
    
    model.add(layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(NUMBER_TIMESTEPS, NUMBER_FEATURES)))
    model.add(layers.MaxPooling1D(pool_size=2))
    model.add(layers.Dropout(0.3))
    
    model.add(Bidirectional(layers.LSTM(256, return_sequences=True, recurrent_dropout=0.2)))
    model.add(Bidirectional(layers.LSTM(128, recurrent_dropout=0.2)))
    
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dropout(0.4))
    
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.3))
    
    model.add(layers.Dense(NUMBER_OUTPUTS, activation='softmax'))

    opt = Adam(learning_rate=0.002)
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy', 
        Precision(name='precision'),
        Recall(name='recall')])
    model.summary()
    return model

# %%
# creating the model
model = build_model()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 148, 64)           39040
#
#  max_pooling1d_3 (MaxPooling  (None, 74, 64)           0
#  1D)
#
#  dropout_9 (Dropout)         (None, 74, 64)            0
#
#  bidirectional_6 (Bidirectio  (None, 74, 512)          657408
#  nal)
#
#  bidirectional_7 (Bidirectio  (None, 256)              656384
#  nal)
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_9 (Dense)             (None, 256)               65792
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 1,452,931
# Trainable params: 1,452,419
# Non-trainable params: 512
# _________________________________________________________________

# %%
# training the model
early_stopping = EarlyStopping(
    monitor='loss',
    patience=5,                # how many epochs to wait before stopping
    restore_best_weights=True # restores the best weights seen during training
)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)

history = model.fit(X_train, y_train, epochs=100, batch_size=len_train, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1745 - accuracy: 0.3333 - precision: 0.5000 - recall: 0.1587WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 6s 6s/step - loss: 1.1745 - accuracy: 0.3333 - precision: 0.5000 - recall: 0.1587 - lr: 0.0020
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8940 - accuracy: 0.5397 - precision: 0.6316 - recall: 0.3810WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 744ms/step - loss: 0.8940 - accuracy: 0.5397 - precision: 0.6316 - recall: 0.3810 - lr: 0.0020
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8210 - accuracy: 0.6190 - precision: 0.6042 - recall: 0.4603WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 736ms/step - loss: 0.8210 - accuracy: 0.6190 - precision: 0.6042 - recall: 0.4603 - lr: 0.0020
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6279 - accuracy: 0.6984 - precision: 0.7455 - recall: 0.6508WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 762ms/step - loss: 0.6279 - accuracy: 0.6984 - precision: 0.7455 - recall: 0.6508 - lr: 0.0020
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7170 - accuracy: 0.7937 - precision: 0.7885 - recall: 0.6508WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 734ms/step - loss: 0.7170 - accuracy: 0.7937 - precision: 0.7885 - recall: 0.6508 - lr: 0.0020
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5322 - accuracy: 0.7460 - precision: 0.7627 - recall: 0.7143WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 745ms/step - loss: 0.5322 - accuracy: 0.7460 - precision: 0.7627 - recall: 0.7143 - lr: 0.0020
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4635 - accuracy: 0.8413 - precision: 0.8667 - recall: 0.8254WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 773ms/step - loss: 0.4635 - accuracy: 0.8413 - precision: 0.8667 - recall: 0.8254 - lr: 0.0020
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3948 - accuracy: 0.8095 - precision: 0.8226 - recall: 0.8095WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 719ms/step - loss: 0.3948 - accuracy: 0.8095 - precision: 0.8226 - recall: 0.8095 - lr: 0.0020
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3924 - accuracy: 0.8413 - precision: 0.8387 - recall: 0.8254WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 750ms/step - loss: 0.3924 - accuracy: 0.8413 - precision: 0.8387 - recall: 0.8254 - lr: 0.0020
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3613 - accuracy: 0.8571 - precision: 0.8689 - recall: 0.8413WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 808ms/step - loss: 0.3613 - accuracy: 0.8571 - precision: 0.8689 - recall: 0.8413 - lr: 0.0020
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5685 - accuracy: 0.8413 - precision: 0.8413 - recall: 0.8413WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 756ms/step - loss: 0.5685 - accuracy: 0.8413 - precision: 0.8413 - recall: 0.8413 - lr: 0.0020
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3192 - accuracy: 0.8730 - precision: 0.8730 - recall: 0.8730WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 786ms/step - loss: 0.3192 - accuracy: 0.8730 - precision: 0.8730 - recall: 0.8730 - lr: 0.0020
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.9206 - precision: 0.9355 - recall: 0.9206WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 796ms/step - loss: 0.2713 - accuracy: 0.9206 - precision: 0.9355 - recall: 0.9206 - lr: 0.0020
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8889 - precision: 0.8871 - recall: 0.8730WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 763ms/step - loss: 0.3328 - accuracy: 0.8889 - precision: 0.8871 - recall: 0.8730 - lr: 0.0020
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9365 - precision: 0.9508 - recall: 0.9206WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 804ms/step - loss: 0.1877 - accuracy: 0.9365 - precision: 0.9508 - recall: 0.9206 - lr: 0.0020
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3012 - accuracy: 0.8730 - precision: 0.8871 - recall: 0.8730WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 803ms/step - loss: 0.3012 - accuracy: 0.8730 - precision: 0.8871 - recall: 0.8730 - lr: 0.0020
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 804ms/step - loss: 0.1800 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206 - lr: 0.0020
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1874 - accuracy: 0.9365 - precision: 0.9365 - recall: 0.9365WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 776ms/step - loss: 0.1874 - accuracy: 0.9365 - precision: 0.9365 - recall: 0.9365 - lr: 0.0020
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 795ms/step - loss: 0.1502 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206 - lr: 0.0020
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.8571 - precision: 0.8571 - recall: 0.8571WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 815ms/step - loss: 0.3149 - accuracy: 0.8571 - precision: 0.8571 - recall: 0.8571 - lr: 0.0020
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1923 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 787ms/step - loss: 0.1923 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206 - lr: 0.0020
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3697 - accuracy: 0.8571 - precision: 0.8571 - recall: 0.8571WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 781ms/step - loss: 0.3697 - accuracy: 0.8571 - precision: 0.8571 - recall: 0.8571 - lr: 0.0020
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 785ms/step - loss: 0.1615 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - lr: 0.0020
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1296 - accuracy: 0.9841 - precision: 0.9841 - recall: 0.9841WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 773ms/step - loss: 0.1296 - accuracy: 0.9841 - precision: 0.9841 - recall: 0.9841 - lr: 0.0020
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.8730 - precision: 0.8730 - recall: 0.8730WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 790ms/step - loss: 0.2905 - accuracy: 0.8730 - precision: 0.8730 - recall: 0.8730 - lr: 0.0020
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9683 - precision: 0.9683 - recall: 0.9683WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 771ms/step - loss: 0.1107 - accuracy: 0.9683 - precision: 0.9683 - recall: 0.9683 - lr: 0.0020
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2446 - accuracy: 0.8730 - precision: 0.8730 - recall: 0.8730WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 769ms/step - loss: 0.2446 - accuracy: 0.8730 - precision: 0.8730 - recall: 0.8730 - lr: 0.0020
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.9048 - precision: 0.9016 - recall: 0.8730WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 788ms/step - loss: 0.2889 - accuracy: 0.9048 - precision: 0.9016 - recall: 0.8730 - lr: 0.0020
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 775ms/step - loss: 0.2374 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - lr: 0.0020
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 795ms/step - loss: 0.0846 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - lr: 0.0020
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 763ms/step - loss: 0.1758 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - lr: 0.0020
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2600 - accuracy: 0.9048 - precision: 0.9048 - recall: 0.9048WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 764ms/step - loss: 0.2600 - accuracy: 0.9048 - precision: 0.9048 - recall: 0.9048 - lr: 0.0020
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1514 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 789ms/step - loss: 0.1514 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - lr: 0.0020
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 748ms/step - loss: 0.2317 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206 - lr: 0.0020
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2320 - accuracy: 0.9048 - precision: 0.9048 - recall: 0.9048WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision,recall,lr
# 1/1 [==============================] - 1s 760ms/step - loss: 0.2320 - accuracy: 0.9048 - precision: 0.9048 - recall: 0.9048 - lr: 0.0020

# %%
train_loss, train_acc, train_precision, train_recall = model.evaluate(X_train, y_train, batch_size=len_train)
# Out:
# 1/1 [==============================] - 0s 245ms/step - loss: 0.3306 - accuracy: 0.8730 - precision: 0.8871 - recall: 0.8730

# %%
# testing the model
test_loss, test_acc, percision, recall = model.evaluate(X_test, y_test, batch_size=len_train)
# Out:
# 1/1 [==============================] - 0s 133ms/step - loss: 0.2953 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9375

# %%
y_probs  = model.predict(X_test)
y_pred = np.zeros_like(y_probs)
y_pred[np.arange(len(y_probs)), y_probs.argmax(1)] = 1
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
matches = np.all(y_pred == y_test, axis=1)  # Boolean array
total_matches = matches.sum()
match_rate = total_matches / float(len(matches))

print('Total matches: %d' % total_matches)
print('Match rate: %.2f' % match_rate)
# Out:
# Total matches: 15
# Match rate: 0.94

# %%
model.save("../model/gesture_model_bidirectional.h5")  # or use .keras instead of .h5

# %%
# VISUAL: Training Curves (2x2 Grid)
plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.title("Loss")
plt.xlabel("Epoch")
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(history.history['precision'], label='Precision')
plt.title("Precision")
plt.xlabel("Epoch")
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(history.history['recall'], label='Recall')
plt.title("Recall")
plt.xlabel("Epoch")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Predict class probabilities
y_pred_probs = model.predict(X_test)

# Convert probabilities to class indices
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

# Generate confusion matrix
cm = confusion_matrix(y_true, y_pred)
class_names = ['RO', 'MA', 'Imposter']

# Plot
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 [==============================] - 0s 150ms/step
